# %% [markdown]
# # Installation

# %%
import pandas as pd
import numpy as np
import requests
import time

# %%
API_KEY = '60a75a67001df36d1cc057304041449a4bfcbd91'

# %% [markdown]
# # Merging Datasets

# %%
zhvi = pd.read_csv('zhvi_county.csv')
# print(zhvi)

# %%
State = 'CA'

state_filtered_data = zhvi[zhvi['State'] == State]
state_region_names = state_filtered_data['RegionName'].unique()

state_region_ids = ''
# print(state_region_names)

# %%
factors = {
    "S0101":  "Age and Sex",
    "S1401": "School Enrollment",
    "S2403" : "Industry by Sex for the Civilian Employed Population 16 Years and Over" 
}

# %%
def get_cencus_data(year, factor, county):
    url = f"https://api.census.gov/data/{year}/acs/acs1/subject?get=group({factor})&ucgid=0500000US{county}"
    print(url)
    response = requests.get(url)
    data = response.json()
    columns = data[0]
    rows = data[1:]
    df = pd.DataFrame(rows, columns=columns)
    return df

def get_variables(year, factor):
    url = f"https://api.census.gov/data/{year}/acs/acs1/subject/groups/{factor}"
    print(url)
    response = requests.get(url)
    time.sleep(2)
    data = response.json()
    return data['variables']

year, factor, county = "2012", list(factors)[2], '06059'
df = get_cencus_data(year, factor, county)
variables = get_variables(year, factor)
# Out:
# https://api.census.gov/data/2012/acs/acs1/subject?get=group(S2403)&ucgid=0500000US06059
# https://api.census.gov/data/2012/acs/acs1/subject/groups/S2403

# %%
for col in range(2, len(df.columns)-1):
    id = df.columns[col]
    print(f"column id: {id}, name: {variables[id]['label']} \n")
# Out:
# column id: S2403_C01_001E, name: Total!!Estimate!!Civilian employed population 16 years and over
#
# column id: S2403_C01_001EA, name: Annotation of Total!!Estimate!!Civilian employed population 16 years and over
#
# column id: S2403_C01_001M, name: Total!!Margin of Error!!Civilian employed population 16 years and over
#
# column id: S2403_C01_001MA, name: Annotation of Total!!Margin of Error!!Civilian employed population 16 years and over
#
# column id: S2403_C01_002E, name: Total!!Estimate!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C01_002EA, name: Annotation of Total!!Estimate!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C01_002M, name: Total!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C01_002MA, name: Annotation of Total!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C01_003E, name: Total!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C01_003EA, name: Annotation of Total!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C01_003M, name: Total!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C01_003MA, name: Annotation of Total!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C01_004E, name: Total!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C01_004EA, name: Annotation of Total!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C01_004M, name: Total!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C01_004MA, name: Annotation of Total!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C01_005E, name: Total!!Estimate!!Construction
#
# column id: S2403_C01_005EA, name: Annotation of Total!!Estimate!!Construction
#
# column id: S2403_C01_005M, name: Total!!Margin of Error!!Construction
#
# column id: S2403_C01_005MA, name: Annotation of Total!!Margin of Error!!Construction
#
# column id: S2403_C01_006E, name: Total!!Estimate!!Manufacturing
#
# column id: S2403_C01_006EA, name: Annotation of Total!!Estimate!!Manufacturing
#
# column id: S2403_C01_006M, name: Total!!Margin of Error!!Manufacturing
#
# column id: S2403_C01_006MA, name: Annotation of Total!!Margin of Error!!Manufacturing
#
# column id: S2403_C01_007E, name: Total!!Estimate!!Wholesale trade
#
# column id: S2403_C01_007EA, name: Annotation of Total!!Estimate!!Wholesale trade
#
# column id: S2403_C01_007M, name: Total!!Margin of Error!!Wholesale trade
#
# column id: S2403_C01_007MA, name: Annotation of Total!!Margin of Error!!Wholesale trade
#
# column id: S2403_C01_008E, name: Total!!Estimate!!Retail trade
#
# column id: S2403_C01_008EA, name: Annotation of Total!!Estimate!!Retail trade
#
# column id: S2403_C01_008M, name: Total!!Margin of Error!!Retail trade
#
# column id: S2403_C01_008MA, name: Annotation of Total!!Margin of Error!!Retail trade
#
# column id: S2403_C01_009E, name: Total!!Estimate!!Transportation and warehousing, and utilities
#
# column id: S2403_C01_009EA, name: Annotation of Total!!Estimate!!Transportation and warehousing, and utilities
#
# column id: S2403_C01_009M, name: Total!!Margin of Error!!Transportation and warehousing, and utilities
#
# column id: S2403_C01_009MA, name: Annotation of Total!!Margin of Error!!Transportation and warehousing, and utilities
#
# column id: S2403_C01_010E, name: Total!!Estimate!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C01_010EA, name: Annotation of Total!!Estimate!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C01_010M, name: Total!!Margin of Error!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C01_010MA, name: Annotation of Total!!Margin of Error!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C01_011E, name: Total!!Estimate!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C01_011EA, name: Annotation of Total!!Estimate!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C01_011M, name: Total!!Margin of Error!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C01_011MA, name: Annotation of Total!!Margin of Error!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C01_012E, name: Total!!Estimate!!Information
#
# column id: S2403_C01_012EA, name: Annotation of Total!!Estimate!!Information
#
# column id: S2403_C01_012M, name: Total!!Margin of Error!!Information
#
# column id: S2403_C01_012MA, name: Annotation of Total!!Margin of Error!!Information
#
# column id: S2403_C01_013E, name: Total!!Estimate!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C01_013EA, name: Annotation of Total!!Estimate!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C01_013M, name: Total!!Margin of Error!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C01_013MA, name: Annotation of Total!!Margin of Error!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C01_014E, name: Total!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C01_014EA, name: Annotation of Total!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C01_014M, name: Total!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C01_014MA, name: Annotation of Total!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C01_015E, name: Total!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C01_015EA, name: Annotation of Total!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C01_015M, name: Total!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C01_015MA, name: Annotation of Total!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C01_016E, name: Total!!Estimate!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C01_016EA, name: Annotation of Total!!Estimate!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C01_016M, name: Total!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C01_016MA, name: Annotation of Total!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C01_017E, name: Total!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C01_017EA, name: Annotation of Total!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C01_017M, name: Total!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C01_017MA, name: Annotation of Total!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C01_018E, name: Total!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C01_018EA, name: Annotation of Total!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C01_018M, name: Total!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C01_018MA, name: Annotation of Total!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C01_019E, name: Total!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C01_019EA, name: Annotation of Total!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C01_019M, name: Total!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C01_019MA, name: Annotation of Total!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C01_020E, name: Total!!Estimate!!Educational services, and health care and social assistance
#
# column id: S2403_C01_020EA, name: Annotation of Total!!Estimate!!Educational services, and health care and social assistance
#
# column id: S2403_C01_020M, name: Total!!Margin of Error!!Educational services, and health care and social assistance
#
# column id: S2403_C01_020MA, name: Annotation of Total!!Margin of Error!!Educational services, and health care and social assistance
#
# column id: S2403_C01_021E, name: Total!!Estimate!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C01_021EA, name: Annotation of Total!!Estimate!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C01_021M, name: Total!!Margin of Error!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C01_021MA, name: Annotation of Total!!Margin of Error!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C01_022E, name: Total!!Estimate!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C01_022EA, name: Annotation of Total!!Estimate!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C01_022M, name: Total!!Margin of Error!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C01_022MA, name: Annotation of Total!!Margin of Error!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C01_023E, name: Total!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C01_023EA, name: Annotation of Total!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C01_023M, name: Total!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C01_023MA, name: Annotation of Total!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C01_024E, name: Total!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C01_024EA, name: Annotation of Total!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C01_024M, name: Total!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C01_024MA, name: Annotation of Total!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C01_025E, name: Total!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C01_025EA, name: Annotation of Total!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C01_025M, name: Total!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C01_025MA, name: Annotation of Total!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C01_026E, name: Total!!Estimate!!Other services, except public administration
#
# column id: S2403_C01_026EA, name: Annotation of Total!!Estimate!!Other services, except public administration
#
# column id: S2403_C01_026M, name: Total!!Margin of Error!!Other services, except public administration
#
# column id: S2403_C01_026MA, name: Annotation of Total!!Margin of Error!!Other services, except public administration
#
# column id: S2403_C01_027E, name: Total!!Estimate!!Public administration
#
# column id: S2403_C01_027EA, name: Annotation of Total!!Estimate!!Public administration
#
# column id: S2403_C01_027M, name: Total!!Margin of Error!!Public administration
#
# column id: S2403_C01_027MA, name: Annotation of Total!!Margin of Error!!Public administration
#
# column id: S2403_C01_028E, name: Total!!Estimate!!PERCENT IMPUTED!!Industry
#
# column id: S2403_C01_028EA, name: Annotation of Total!!Estimate!!PERCENT IMPUTED!!Industry
#
# column id: S2403_C01_028M, name: Total!!Margin of Error!!PERCENT IMPUTED!!Industry
#
# column id: S2403_C01_028MA, name: Annotation of Total!!Margin of Error!!PERCENT IMPUTED!!Industry
#
# column id: S2403_C02_001E, name: Male!!Estimate!!Civilian employed population 16 years and over
#
# column id: S2403_C02_001EA, name: Annotation of Male!!Estimate!!Civilian employed population 16 years and over
#
# column id: S2403_C02_001M, name: Male!!Margin of Error!!Civilian employed population 16 years and over
#
# column id: S2403_C02_001MA, name: Annotation of Male!!Margin of Error!!Civilian employed population 16 years and over
#
# column id: S2403_C02_002E, name: Male!!Estimate!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C02_002EA, name: Annotation of Male!!Estimate!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C02_002M, name: Male!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C02_002MA, name: Annotation of Male!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C02_003E, name: Male!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C02_003EA, name: Annotation of Male!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C02_003M, name: Male!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C02_003MA, name: Annotation of Male!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C02_004E, name: Male!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C02_004EA, name: Annotation of Male!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C02_004M, name: Male!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C02_004MA, name: Annotation of Male!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C02_005E, name: Male!!Estimate!!Construction
#
# column id: S2403_C02_005EA, name: Annotation of Male!!Estimate!!Construction
#
# column id: S2403_C02_005M, name: Male!!Margin of Error!!Construction
#
# column id: S2403_C02_005MA, name: Annotation of Male!!Margin of Error!!Construction
#
# column id: S2403_C02_006E, name: Male!!Estimate!!Manufacturing
#
# column id: S2403_C02_006EA, name: Annotation of Male!!Estimate!!Manufacturing
#
# column id: S2403_C02_006M, name: Male!!Margin of Error!!Manufacturing
#
# column id: S2403_C02_006MA, name: Annotation of Male!!Margin of Error!!Manufacturing
#
# column id: S2403_C02_007E, name: Male!!Estimate!!Wholesale trade
#
# column id: S2403_C02_007EA, name: Annotation of Male!!Estimate!!Wholesale trade
#
# column id: S2403_C02_007M, name: Male!!Margin of Error!!Wholesale trade
#
# column id: S2403_C02_007MA, name: Annotation of Male!!Margin of Error!!Wholesale trade
#
# column id: S2403_C02_008E, name: Male!!Estimate!!Retail trade
#
# column id: S2403_C02_008EA, name: Annotation of Male!!Estimate!!Retail trade
#
# column id: S2403_C02_008M, name: Male!!Margin of Error!!Retail trade
#
# column id: S2403_C02_008MA, name: Annotation of Male!!Margin of Error!!Retail trade
#
# column id: S2403_C02_009E, name: Male!!Estimate!!Transportation and warehousing, and utilities
#
# column id: S2403_C02_009EA, name: Annotation of Male!!Estimate!!Transportation and warehousing, and utilities
#
# column id: S2403_C02_009M, name: Male!!Margin of Error!!Transportation and warehousing, and utilities
#
# column id: S2403_C02_009MA, name: Annotation of Male!!Margin of Error!!Transportation and warehousing, and utilities
#
# column id: S2403_C02_010E, name: Male!!Estimate!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C02_010EA, name: Annotation of Male!!Estimate!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C02_010M, name: Male!!Margin of Error!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C02_010MA, name: Annotation of Male!!Margin of Error!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C02_011E, name: Male!!Estimate!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C02_011EA, name: Annotation of Male!!Estimate!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C02_011M, name: Male!!Margin of Error!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C02_011MA, name: Annotation of Male!!Margin of Error!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C02_012E, name: Male!!Estimate!!Information
#
# column id: S2403_C02_012EA, name: Annotation of Male!!Estimate!!Information
#
# column id: S2403_C02_012M, name: Male!!Margin of Error!!Information
#
# column id: S2403_C02_012MA, name: Annotation of Male!!Margin of Error!!Information
#
# column id: S2403_C02_013E, name: Male!!Estimate!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C02_013EA, name: Annotation of Male!!Estimate!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C02_013M, name: Male!!Margin of Error!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C02_013MA, name: Annotation of Male!!Margin of Error!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C02_014E, name: Male!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C02_014EA, name: Annotation of Male!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C02_014M, name: Male!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C02_014MA, name: Annotation of Male!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C02_015E, name: Male!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C02_015EA, name: Annotation of Male!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C02_015M, name: Male!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C02_015MA, name: Annotation of Male!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C02_016E, name: Male!!Estimate!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C02_016EA, name: Annotation of Male!!Estimate!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C02_016M, name: Male!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C02_016MA, name: Annotation of Male!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C02_017E, name: Male!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C02_017EA, name: Annotation of Male!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C02_017M, name: Male!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C02_017MA, name: Annotation of Male!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C02_018E, name: Male!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C02_018EA, name: Annotation of Male!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C02_018M, name: Male!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C02_018MA, name: Annotation of Male!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C02_019E, name: Male!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C02_019EA, name: Annotation of Male!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C02_019M, name: Male!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C02_019MA, name: Annotation of Male!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C02_020E, name: Male!!Estimate!!Educational services, and health care and social assistance
#
# column id: S2403_C02_020EA, name: Annotation of Male!!Estimate!!Educational services, and health care and social assistance
#
# column id: S2403_C02_020M, name: Male!!Margin of Error!!Educational services, and health care and social assistance
#
# column id: S2403_C02_020MA, name: Annotation of Male!!Margin of Error!!Educational services, and health care and social assistance
#
# column id: S2403_C02_021E, name: Male!!Estimate!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C02_021EA, name: Annotation of Male!!Estimate!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C02_021M, name: Male!!Margin of Error!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C02_021MA, name: Annotation of Male!!Margin of Error!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C02_022E, name: Male!!Estimate!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C02_022EA, name: Annotation of Male!!Estimate!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C02_022M, name: Male!!Margin of Error!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C02_022MA, name: Annotation of Male!!Margin of Error!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C02_023E, name: Male!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C02_023EA, name: Annotation of Male!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C02_023M, name: Male!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C02_023MA, name: Annotation of Male!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C02_024E, name: Male!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C02_024EA, name: Annotation of Male!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C02_024M, name: Male!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C02_024MA, name: Annotation of Male!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C02_025E, name: Male!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C02_025EA, name: Annotation of Male!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C02_025M, name: Male!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C02_025MA, name: Annotation of Male!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C02_026E, name: Male!!Estimate!!Other services, except public administration
#
# column id: S2403_C02_026EA, name: Annotation of Male!!Estimate!!Other services, except public administration
#
# column id: S2403_C02_026M, name: Male!!Margin of Error!!Other services, except public administration
#
# column id: S2403_C02_026MA, name: Annotation of Male!!Margin of Error!!Other services, except public administration
#
# column id: S2403_C02_027E, name: Male!!Estimate!!Public administration
#
# column id: S2403_C02_027EA, name: Annotation of Male!!Estimate!!Public administration
#
# column id: S2403_C02_027M, name: Male!!Margin of Error!!Public administration
#
# column id: S2403_C02_027MA, name: Annotation of Male!!Margin of Error!!Public administration
#
# column id: S2403_C02_028E, name: Male!!Estimate!!PERCENT IMPUTED!!Industry
#
# column id: S2403_C02_028EA, name: Annotation of Male!!Estimate!!PERCENT IMPUTED!!Industry
#
# column id: S2403_C02_028M, name: Male!!Margin of Error!!PERCENT IMPUTED!!Industry
#
# column id: S2403_C02_028MA, name: Annotation of Male!!Margin of Error!!PERCENT IMPUTED!!Industry
#
# column id: S2403_C03_001E, name: Female!!Estimate!!Civilian employed population 16 years and over
#
# column id: S2403_C03_001EA, name: Annotation of Female!!Estimate!!Civilian employed population 16 years and over
#
# column id: S2403_C03_001M, name: Female!!Margin of Error!!Civilian employed population 16 years and over
#
# column id: S2403_C03_001MA, name: Annotation of Female!!Margin of Error!!Civilian employed population 16 years and over
#
# column id: S2403_C03_002E, name: Female!!Estimate!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C03_002EA, name: Annotation of Female!!Estimate!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C03_002M, name: Female!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C03_002MA, name: Annotation of Female!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C03_003E, name: Female!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C03_003EA, name: Annotation of Female!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C03_003M, name: Female!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C03_003MA, name: Annotation of Female!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C03_004E, name: Female!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C03_004EA, name: Annotation of Female!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C03_004M, name: Female!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C03_004MA, name: Annotation of Female!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C03_005E, name: Female!!Estimate!!Construction
#
# column id: S2403_C03_005EA, name: Annotation of Female!!Estimate!!Construction
#
# column id: S2403_C03_005M, name: Female!!Margin of Error!!Construction
#
# column id: S2403_C03_005MA, name: Annotation of Female!!Margin of Error!!Construction
#
# column id: S2403_C03_006E, name: Female!!Estimate!!Manufacturing
#
# column id: S2403_C03_006EA, name: Annotation of Female!!Estimate!!Manufacturing
#
# column id: S2403_C03_006M, name: Female!!Margin of Error!!Manufacturing
#
# column id: S2403_C03_006MA, name: Annotation of Female!!Margin of Error!!Manufacturing
#
# column id: S2403_C03_007E, name: Female!!Estimate!!Wholesale trade
#
# column id: S2403_C03_007EA, name: Annotation of Female!!Estimate!!Wholesale trade
#
# column id: S2403_C03_007M, name: Female!!Margin of Error!!Wholesale trade
#
# column id: S2403_C03_007MA, name: Annotation of Female!!Margin of Error!!Wholesale trade
#
# column id: S2403_C03_008E, name: Female!!Estimate!!Retail trade
#
# column id: S2403_C03_008EA, name: Annotation of Female!!Estimate!!Retail trade
#
# column id: S2403_C03_008M, name: Female!!Margin of Error!!Retail trade
#
# column id: S2403_C03_008MA, name: Annotation of Female!!Margin of Error!!Retail trade
#
# column id: S2403_C03_009E, name: Female!!Estimate!!Transportation and warehousing, and utilities
#
# column id: S2403_C03_009EA, name: Annotation of Female!!Estimate!!Transportation and warehousing, and utilities
#
# column id: S2403_C03_009M, name: Female!!Margin of Error!!Transportation and warehousing, and utilities
#
# column id: S2403_C03_009MA, name: Annotation of Female!!Margin of Error!!Transportation and warehousing, and utilities
#
# column id: S2403_C03_010E, name: Female!!Estimate!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C03_010EA, name: Annotation of Female!!Estimate!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C03_010M, name: Female!!Margin of Error!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C03_010MA, name: Annotation of Female!!Margin of Error!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C03_011E, name: Female!!Estimate!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C03_011EA, name: Annotation of Female!!Estimate!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C03_011M, name: Female!!Margin of Error!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C03_011MA, name: Annotation of Female!!Margin of Error!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C03_012E, name: Female!!Estimate!!Information
#
# column id: S2403_C03_012EA, name: Annotation of Female!!Estimate!!Information
#
# column id: S2403_C03_012M, name: Female!!Margin of Error!!Information
#
# column id: S2403_C03_012MA, name: Annotation of Female!!Margin of Error!!Information
#
# column id: S2403_C03_013E, name: Female!!Estimate!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C03_013EA, name: Annotation of Female!!Estimate!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C03_013M, name: Female!!Margin of Error!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C03_013MA, name: Annotation of Female!!Margin of Error!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C03_014E, name: Female!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C03_014EA, name: Annotation of Female!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C03_014M, name: Female!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C03_014MA, name: Annotation of Female!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C03_015E, name: Female!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C03_015EA, name: Annotation of Female!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C03_015M, name: Female!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C03_015MA, name: Annotation of Female!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C03_016E, name: Female!!Estimate!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C03_016EA, name: Annotation of Female!!Estimate!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C03_016M, name: Female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C03_016MA, name: Annotation of Female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C03_017E, name: Female!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C03_017EA, name: Annotation of Female!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C03_017M, name: Female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C03_017MA, name: Annotation of Female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C03_018E, name: Female!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C03_018EA, name: Annotation of Female!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C03_018M, name: Female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C03_018MA, name: Annotation of Female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C03_019E, name: Female!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C03_019EA, name: Annotation of Female!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C03_019M, name: Female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C03_019MA, name: Annotation of Female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C03_020E, name: Female!!Estimate!!Educational services, and health care and social assistance
#
# column id: S2403_C03_020EA, name: Annotation of Female!!Estimate!!Educational services, and health care and social assistance
#
# column id: S2403_C03_020M, name: Female!!Margin of Error!!Educational services, and health care and social assistance
#
# column id: S2403_C03_020MA, name: Annotation of Female!!Margin of Error!!Educational services, and health care and social assistance
#
# column id: S2403_C03_021E, name: Female!!Estimate!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C03_021EA, name: Annotation of Female!!Estimate!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C03_021M, name: Female!!Margin of Error!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C03_021MA, name: Annotation of Female!!Margin of Error!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C03_022E, name: Female!!Estimate!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C03_022EA, name: Annotation of Female!!Estimate!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C03_022M, name: Female!!Margin of Error!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C03_022MA, name: Annotation of Female!!Margin of Error!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C03_023E, name: Female!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C03_023EA, name: Annotation of Female!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C03_023M, name: Female!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C03_023MA, name: Annotation of Female!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C03_024E, name: Female!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C03_024EA, name: Annotation of Female!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C03_024M, name: Female!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C03_024MA, name: Annotation of Female!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C03_025E, name: Female!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C03_025EA, name: Annotation of Female!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C03_025M, name: Female!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C03_025MA, name: Annotation of Female!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C03_026E, name: Female!!Estimate!!Other services, except public administration
#
# column id: S2403_C03_026EA, name: Annotation of Female!!Estimate!!Other services, except public administration
#
# column id: S2403_C03_026M, name: Female!!Margin of Error!!Other services, except public administration
#
# column id: S2403_C03_026MA, name: Annotation of Female!!Margin of Error!!Other services, except public administration
#
# column id: S2403_C03_027E, name: Female!!Estimate!!Public administration
#
# column id: S2403_C03_027EA, name: Annotation of Female!!Estimate!!Public administration
#
# column id: S2403_C03_027M, name: Female!!Margin of Error!!Public administration
#
# column id: S2403_C03_027MA, name: Annotation of Female!!Margin of Error!!Public administration
#
# column id: S2403_C03_028E, name: Female!!Estimate!!PERCENT IMPUTED!!Industry
#
# column id: S2403_C03_028EA, name: Annotation of Female!!Estimate!!PERCENT IMPUTED!!Industry
#
# column id: S2403_C03_028M, name: Female!!Margin of Error!!PERCENT IMPUTED!!Industry
#
# column id: S2403_C03_028MA, name: Annotation of Female!!Margin of Error!!PERCENT IMPUTED!!Industry
#
# column id: S2403_C04_001E, name: Median earnings (dollars)!!Estimate!!Civilian employed population 16 years and over
#
# column id: S2403_C04_001EA, name: Annotation of Median earnings (dollars)!!Estimate!!Civilian employed population 16 years and over
#
# column id: S2403_C04_001M, name: Median earnings (dollars)!!Margin of Error!!Civilian employed population 16 years and over
#
# column id: S2403_C04_001MA, name: Annotation of Median earnings (dollars)!!Margin of Error!!Civilian employed population 16 years and over
#
# column id: S2403_C04_002E, name: Median earnings (dollars)!!Estimate!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C04_002EA, name: Annotation of Median earnings (dollars)!!Estimate!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C04_002M, name: Median earnings (dollars)!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C04_002MA, name: Annotation of Median earnings (dollars)!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining
#
# column id: S2403_C04_003E, name: Median earnings (dollars)!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C04_003EA, name: Annotation of Median earnings (dollars)!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C04_003M, name: Median earnings (dollars)!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C04_003MA, name: Annotation of Median earnings (dollars)!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Agriculture, forestry, fishing and hunting
#
# column id: S2403_C04_004E, name: Median earnings (dollars)!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C04_004EA, name: Annotation of Median earnings (dollars)!!Estimate!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C04_004M, name: Median earnings (dollars)!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C04_004MA, name: Annotation of Median earnings (dollars)!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C04_005E, name: Median earnings (dollars)!!Estimate!!Construction
#
# column id: S2403_C04_005EA, name: Annotation of Median earnings (dollars)!!Estimate!!Construction
#
# column id: S2403_C04_005M, name: Median earnings (dollars)!!Margin of Error!!Construction
#
# column id: S2403_C04_005MA, name: Annotation of Median earnings (dollars)!!Margin of Error!!Construction
#
# column id: S2403_C04_006E, name: Median earnings (dollars)!!Estimate!!Manufacturing
#
# column id: S2403_C04_006EA, name: Annotation of Median earnings (dollars)!!Estimate!!Manufacturing
#
# column id: S2403_C04_006M, name: Median earnings (dollars)!!Margin of Error!!Manufacturing
#
# column id: S2403_C04_006MA, name: Annotation of Median earnings (dollars)!!Margin of Error!!Manufacturing
#
# column id: S2403_C04_007E, name: Median earnings (dollars)!!Estimate!!Wholesale trade
#
# column id: S2403_C04_007EA, name: Annotation of Median earnings (dollars)!!Estimate!!Wholesale trade
#
# column id: S2403_C04_007M, name: Median earnings (dollars)!!Margin of Error!!Wholesale trade
#
# ...
#
# column id: S2403_C06_004M, name: Median earnings (dollars) for female!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C06_004MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction
#
# column id: S2403_C06_005E, name: Median earnings (dollars) for female!!Estimate!!Construction
#
# column id: S2403_C06_005EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Construction
#
# column id: S2403_C06_005M, name: Median earnings (dollars) for female!!Margin of Error!!Construction
#
# column id: S2403_C06_005MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Construction
#
# column id: S2403_C06_006E, name: Median earnings (dollars) for female!!Estimate!!Manufacturing
#
# column id: S2403_C06_006EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Manufacturing
#
# column id: S2403_C06_006M, name: Median earnings (dollars) for female!!Margin of Error!!Manufacturing
#
# column id: S2403_C06_006MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Manufacturing
#
# column id: S2403_C06_007E, name: Median earnings (dollars) for female!!Estimate!!Wholesale trade
#
# column id: S2403_C06_007EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Wholesale trade
#
# column id: S2403_C06_007M, name: Median earnings (dollars) for female!!Margin of Error!!Wholesale trade
#
# column id: S2403_C06_007MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Wholesale trade
#
# column id: S2403_C06_008E, name: Median earnings (dollars) for female!!Estimate!!Retail trade
#
# column id: S2403_C06_008EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Retail trade
#
# column id: S2403_C06_008M, name: Median earnings (dollars) for female!!Margin of Error!!Retail trade
#
# column id: S2403_C06_008MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Retail trade
#
# column id: S2403_C06_009E, name: Median earnings (dollars) for female!!Estimate!!Transportation and warehousing, and utilities
#
# column id: S2403_C06_009EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Transportation and warehousing, and utilities
#
# column id: S2403_C06_009M, name: Median earnings (dollars) for female!!Margin of Error!!Transportation and warehousing, and utilities
#
# column id: S2403_C06_009MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Transportation and warehousing, and utilities
#
# column id: S2403_C06_010E, name: Median earnings (dollars) for female!!Estimate!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C06_010EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C06_010M, name: Median earnings (dollars) for female!!Margin of Error!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C06_010MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Transportation and warehousing, and utilities!!Transportation and warehousing
#
# column id: S2403_C06_011E, name: Median earnings (dollars) for female!!Estimate!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C06_011EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C06_011M, name: Median earnings (dollars) for female!!Margin of Error!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C06_011MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Transportation and warehousing, and utilities!!Utilities
#
# column id: S2403_C06_012E, name: Median earnings (dollars) for female!!Estimate!!Information
#
# column id: S2403_C06_012EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Information
#
# column id: S2403_C06_012M, name: Median earnings (dollars) for female!!Margin of Error!!Information
#
# column id: S2403_C06_012MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Information
#
# column id: S2403_C06_013E, name: Median earnings (dollars) for female!!Estimate!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C06_013EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C06_013M, name: Median earnings (dollars) for female!!Margin of Error!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C06_013MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Finance and insurance, and real estate and rental and leasing
#
# column id: S2403_C06_014E, name: Median earnings (dollars) for female!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C06_014EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C06_014M, name: Median earnings (dollars) for female!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C06_014MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance
#
# column id: S2403_C06_015E, name: Median earnings (dollars) for female!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C06_015EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C06_015M, name: Median earnings (dollars) for female!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C06_015MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing
#
# column id: S2403_C06_016E, name: Median earnings (dollars) for female!!Estimate!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C06_016EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C06_016M, name: Median earnings (dollars) for female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C06_016MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services
#
# column id: S2403_C06_017E, name: Median earnings (dollars) for female!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C06_017EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C06_017M, name: Median earnings (dollars) for female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C06_017MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services
#
# column id: S2403_C06_018E, name: Median earnings (dollars) for female!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C06_018EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C06_018M, name: Median earnings (dollars) for female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C06_018MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises
#
# column id: S2403_C06_019E, name: Median earnings (dollars) for female!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C06_019EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C06_019M, name: Median earnings (dollars) for female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C06_019MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services
#
# column id: S2403_C06_020E, name: Median earnings (dollars) for female!!Estimate!!Educational services, and health care and social assistance
#
# column id: S2403_C06_020EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Educational services, and health care and social assistance
#
# column id: S2403_C06_020M, name: Median earnings (dollars) for female!!Margin of Error!!Educational services, and health care and social assistance
#
# column id: S2403_C06_020MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Educational services, and health care and social assistance
#
# column id: S2403_C06_021E, name: Median earnings (dollars) for female!!Estimate!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C06_021EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C06_021M, name: Median earnings (dollars) for female!!Margin of Error!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C06_021MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Educational services, and health care and social assistance!!Educational services
#
# column id: S2403_C06_022E, name: Median earnings (dollars) for female!!Estimate!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C06_022EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C06_022M, name: Median earnings (dollars) for female!!Margin of Error!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C06_022MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Educational services, and health care and social assistance!!Health care and social assistance
#
# column id: S2403_C06_023E, name: Median earnings (dollars) for female!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C06_023EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C06_023M, name: Median earnings (dollars) for female!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C06_023MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services
#
# column id: S2403_C06_024E, name: Median earnings (dollars) for female!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C06_024EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C06_024M, name: Median earnings (dollars) for female!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C06_024MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Arts, entertainment, and recreation
#
# column id: S2403_C06_025E, name: Median earnings (dollars) for female!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C06_025EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C06_025M, name: Median earnings (dollars) for female!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C06_025MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Arts, entertainment, and recreation, and accommodation and food services!!Accommodation and food services
#
# column id: S2403_C06_026E, name: Median earnings (dollars) for female!!Estimate!!Other services, except public administration
#
# column id: S2403_C06_026EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Other services, except public administration
#
# column id: S2403_C06_026M, name: Median earnings (dollars) for female!!Margin of Error!!Other services, except public administration
#
# column id: S2403_C06_026MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Other services, except public administration
#
# column id: S2403_C06_027E, name: Median earnings (dollars) for female!!Estimate!!Public administration
#
# column id: S2403_C06_027EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!Public administration
#
# column id: S2403_C06_027M, name: Median earnings (dollars) for female!!Margin of Error!!Public administration
#
# column id: S2403_C06_027MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!Public administration
#
# column id: S2403_C06_028E, name: Median earnings (dollars) for female!!Estimate!!PERCENT IMPUTED!!Industry
#
# column id: S2403_C06_028EA, name: Annotation of Median earnings (dollars) for female!!Estimate!!PERCENT IMPUTED!!Industry
#
# column id: S2403_C06_028M, name: Median earnings (dollars) for female!!Margin of Error!!PERCENT IMPUTED!!Industry
#
# column id: S2403_C06_028MA, name: Annotation of Median earnings (dollars) for female!!Margin of Error!!PERCENT IMPUTED!!Industry

# %% [markdown]
# # Uploading data to Neo4j

# %%
df['S2403_C01_001M']
# Out:
# 0    10036
# Name: S2403_C01_001M, dtype: object
